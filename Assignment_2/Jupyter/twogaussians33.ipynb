# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('twogaussians33.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 2, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y, y_kmeans)
print("Accuracy score: {:.2f}".format(accuracy))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score: 0.97

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')

plt.scatter(X[y==0, 0], X[y==0, 1], c='y', label='Original 0',marker='*')
plt.scatter(X[y==1, 0], X[y==1, 1], c='g', label='Original 1',marker='.')

plt.title('K-Means')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()

# %%
from sklearn.mixture import GaussianMixture
em = GaussianMixture(n_components=2, random_state=0)
y_kmeans = em.fit_predict(X)

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y, y_kmeans)
print("Accuracy score: {:.2f}".format(accuracy))
# Out:
# Accuracy score: 0.99

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')

plt.scatter(X[y==0, 0], X[y==0, 1], c='y', label='Original 0',marker='*')
plt.scatter(X[y==1, 0], X[y==1, 1], c='g', label='Original 1',marker='.')

plt.title('GMM')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()

# %%
from sklearn.cluster import SpectralClustering
sc = SpectralClustering(n_clusters=2, affinity='rbf', gamma=1.0)
y_kmeans = sc.fit_predict(X)

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y, y_kmeans)
print("Accuracy score: {:.2f}".format(accuracy))
# Out:
# Accuracy score: 0.98

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')

plt.scatter(X[y==0, 0], X[y==0, 1], c='y', label='Original 0',marker='*')
plt.scatter(X[y==1, 0], X[y==1, 1], c='g', label='Original 1',marker='.')

plt.title('Spectral_Clustering')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method K_Means')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...
